# %% [markdown]
#  # Aufgabe 2.1

# %% [markdown]
# # Aufgabe 2.1.1
# 1-D Furier - Basisfunktion , Orthogonalität
#
# Die 1-D Furier - Basisfunktion ist geggeben durch:
#
# $$
# \varphi_n(x) = e(iq_nx)
# $$
# wobei $ x \in [0, L]$ und $q_n = 2\pi n / L$.
#
#
# Ist das Skalarproduktgleich von zwei Basisvektoren gleich Null, stehen diese Orthogonal zueinander.
# Wir benutzen in unserem Fall $\varphi_n , \varphi_m$.
#
# $$
# (\varphi_n,\varphi_m) = \frac{1}{L} \int_0^L \varphi_n^*  \varphi_m dx
# $$
#
# $$(\varphi_n , \varphi_m )  = \frac{1}{L} \int_0^L e^{-i\frac{2 \pi n}{L}x} \cdot e^{i\frac{2 \pi m}{L}x} dx$$
#
# $$(\varphi_n , \varphi_m ) = \frac{1}{L} \int_0^L e^{i\cdot(m-n)\cdot\frac{2 \pi x}{L}} dx$$
#
#
# Sollte $m = n$ erhalten wird als Lösung die 1.
#
# Sollte $m \neq n$ erhalten wir als Lösung die 0. Dies ist nachfolgend aufgezeigt:
#
#
# $$(\varphi_n , \varphi_m )  = \frac{1}{L} \int_0^L e^{i\frac{2 \pi k}{L}x} dx \\
# $$
#
# $$
# (\varphi_n , \varphi_m ) = \frac{1}{L} ( \int_0^L cos(\frac{2 \pi k}{L}x ) dx + \int_0^L i sin(\frac{2 \pi k}{L}x) dx) \\
# $$
#
#
# Das Integral des cos mit den grenzen 0 , L, wird zu 0 und das Integral des sin mit den Grenzen wird 0,L, jeweils zu 1, daher erhalten wir:
#
#  $$(\varphi_n , \varphi_m ) =  \frac{1}{L} (0 -  0 +  1i -1i) =  0 $$

# %% [markdown]
# # Aufgabe 2.1.2
#
# 2D-Basisfunktion:
# $$
# \varphi_{nm}(x,y) = e^{iq_nx + i q_y} \\
# $$
# $$
# \varphi_{nm}(x,y) = e^{iq_nx} \cdot e^{iq_my}y) \\
# \varphi_{nm}(x,y9 = \varphi_n(x) \cdot \varphi_m(y)\\
# $$
# $q_n$ = $2\pi n / L_x$ $\space\space\space\space$ $q_m$ = $2\pi m / L_y$ $\space\space\space$ $n \in \mathbb{N}$  $\space$ &  $\space$ $m \in \mathbb{N}$
# $\\$
#
# Das Sklarprodukt aus der Basisfunktion $\varphi_{jk}(x,y)$ und $\varphi_{nm}(x,y)$ ist:
#
# $$
# (\varphi_{nm}(x,y),\varphi_{jk}(x,y) ) = \frac{1}{L_xL_y} \int_0^{L_y} \int_0^{L_x} \varphi_{nm}^* \cdot \varphi_{jk} \space dxdy
# $$
# $$
# (\varphi_{nm}(x,y),\varphi_{jk}(x,y) )= \frac{1}{L_xL_y} \int_0^{L_y} \int_0^{L_x}   \varphi_n(x)^* \cdot \varphi_m(y)^* \cdot   \varphi_j(x) \cdot \varphi_k(y) \space dxdy \\
# $$
#
# $$
# (\varphi_{nm}(x,y),\varphi_{jk}(x,y) )= \frac{1}{L_xL_y} \int_0^{L_y} \int_0^{L_x}   \varphi_n(x)^* \cdot  \varphi_j(x)  \cdot   \varphi_m(y)^* \cdot \varphi_k(y) \space dxdy \\
# $$
#
# Nun $ \varphi_n(x)^* \cdot  \varphi_j(x)$ zu  $\delta_{nj}$ zusammengefasst und auch $\varphi_m(y)^* \cdot \varphi_k(y)$ zu $\delta_{mk}$.
#
# $$
# (\varphi_{nm}(x,y),\varphi_{jk}(x,y) ) = \frac{1}{L_xL_y} \int_0^{L_y} \int_0^{L_x} \delta_{nj} \cdot \delta_{mk} ~dxdy = \delta_{nj}  \delta_{mk}
# $$

# %% [markdown]
# # Aufgabe 2.1.3
#
# $$
# f(x,y) = f_N(x,y)
# $$
#
# $$
# f_N(x,y)= \sum_{n=- \space\infty}^{\infty}\sum_{m  = \space -\infty}^{\infty}a_{nm} \cdot \varphi_n(x) \cdot \varphi_m(y)
# $$
#
# Bestimmung des Fourierkoeffizienten durch das Skalarprodukt der festen Basisfunktion:
#
# $$
# (\varphi_j(x)\space \varphi_k(y),f_N(x,y))  = \sum_{n= \space -\infty}^{\infty} \sum_{m= \space -\infty}^{\infty}a_{nm} (\varphi_j(x)\varphi_k(y),\space \varphi_n(x)\varphi_m(y)) \\
# $$
#
# $$
# (\varphi_j(x)\space \varphi_k(y),f_N(x,y) = \sum_{n= \space-\infty}^{\infty}\sum_{m=\space-\infty}^{\infty}a_{nm} L_x \space L_y\space \delta_{nj} \space \delta_{mk} \\
# $$
#
# $$
# (\varphi_j(x)\space \varphi_k(y),f_N(x,y)=  a_{jk}\space L_x \space L_y \\
# $$
# $$
# a_{jk} = (\varphi_j(x) \varphi_k(y), f_N(x,y))\space  / \space  (L_xL_y)
# $$

# %% [markdown]
# # Aufgabe 2.2

# %% [markdown]
# # Aufgabe 2.2.1
#
# Residium der Diffusionsgleichung:
# $$
# R(x)  =  D \frac{\partial^2 c(x) }{\partial x^2}\space - \space f(x) =\space 0
# $$
# Nun wird eine Testfunktion v(x) mit dem Residium multipliziert. Somit wird reduziert man die Differenzierbarkeit.
#
# Das Skalarprodukt hierzu ist wie nachfolgend definiert:
#
# $$
# (f,g) =\int_\Omega f \cdot g \space dx
# $$
#
# Somit lautet die Mulipiliaktion ;
#
# $$
# (v(x),R(x))  = \int_{\Omega} v(x) \cdot R(x)\space dx = 0 \\
# $$
#
# $$
# (v(x),R(x)) = \int_{\Omega}D \cdot v(x) \cdot \frac{\partial^2 c(x)} {\partial x^2}\space dx - \int_{\Omega} v(x)\cdot f(x) \\
# $$
#
# Unter vernachlässigung der Randbedingung erhalten wir:
#
#
#
# $$
# (v(x),R(x))  = - D \cdot \int_{\Omega}  \frac{\partial v(x)}{\partial x}  \cdot \frac{\partial c(x)} {\partial x} \space dx - \int_{\omega} v(x)\cdot  f(x) dx
# $$
#
#
# Nun wird die Testfunktion druch eine Basisfunktion ersetzt ( Glerkin Ansatz).
# Die gesuchte FUntion c(x) wird durch ein Reihe genährt.
# $ c(x)\approx c_N(x) = \sum_{n= \space0}^{N} \space  a_n \varphi_n(x)$
#
# $$
# R_N(x)  = D \frac{\partial^2 c_N(x)}{\partial x^2} - f(x)
# $$
#
# folglich :
#
#
#
# $$
# (\varphi_k(x),R_N(x))   = -D  \sum_{n=0}^{N} a_n ( \frac{\partial \varphi_k\partial \varphi_n}{\partial x}) - (\varphi_k(x),f(x)) = 0 \\
# $$
#
# mit $(\frac{\partial \varphi_k\partial \varphi_n}{\partial x})$ = ${K_{kn}}$  und $(\varphi_k(x),f(x))$ = $\vec{f}$ erhatlen wir :
#
# $$
# = -D \sum_{i=0}^N a_i K_{kn} - \vec{f} = 0 \\
# \vec{a} \cdot \underline{K}  = - (\vec{f} \cdot \frac{1}{D})
# $$

# %% [markdown]
# # Aufgabe 2.2.2
#
# Berechnung des f-Vektors mit Hilfe der zwei gegebenen Quelltermen.
#
# Quellterm 1 : $f_1(x) = -\delta (x-\frac{L}{3}) + \delta (x-\frac{2L}{3})$
#
# $$
# f_k(x)  = \int_{\Omega} \varphi_k(x) f(x) dx \\
# $$
#
# $$
# f_k(x)  = \int_\Omega \varphi_k(x) \cdot ( -\delta(x-L/3) + \delta(x-2L/3))\space dx
# $$
#
# $$
# f_k(x) = - \int_{\Omega} \varphi_k(x) \cdot \delta (x-L/3)) + \int_{\Omega} \varphi_k(x) \cdot \delta (x-2L/3) \\
# $$
#
# $$f_k = -\varphi_k \cdot (L/3) + \varphi_k \cdot (2L/3)$$
#
# Gewählte Knoten bei : $2L/3$ und  $L/3$.
# Damit erhalten wir für den Quellterm $\vec{f}$:
#
# $$
# \vec{f}= \frac{1}{D} \space \left(\begin{array}{c}  \space\space0 \\ \space \space1 \\  -1 \\ \space\space 0 \end{array}\right)
# $$
#
#
# Für  Quellterm Nummer Zwei ; 𝑓(𝑥)=𝑓0 erhalten wir:
#
# $$
# f_k = (\varphi_k,f(x))  = \int_{\Omega} \varphi_k(x)  f_0 \space dx \\
# f_k= f_0 \cdot \int_{\Omega}  \varphi_k(x)  \space dx \\
# f_k= f_0 \cdot (x_{(k+1)} -x_{(k-1)}) \\
# f_k=\Delta x
# $$
#
# $\Delta x$  = Abstand Stützstellen.

# %% [markdown]
# # Aufgabe 2.3.1
#
# Gegebener Mittelwert der Funktioon:
#
# $$
# c_0  = \frac{1}{L}\cdot \int_{\Omega} c(x) \space dx \space \space\space\space\space\space (1)
# $$
#
# $c(x)$ nähert sich $c_N(x)$, somit erhalten wir :
#
#
# $$
# c(x)= \sum_{n= \space0}^N a_n \cdot \varphi_n(x)
# $$
#
# Nach einsetzen der Grenzen §0 und L§ halten wir für $c_0$:
# $$
# c_0 = \frac{1}{L} \int_0^L c_N(x)\space dx
# $$
#
# Nun wir die Funktion (1) eingesetzt:
# $$
# c_0 = \frac{1}{L} \int_0^L \sum_{i=0}^N a_i  \cdot \varphi_i(x) \space dx
# $$
#
# $$
# c_0 = \frac{1}{L}\cdot ( a_0 \int_0^L \varphi_0(x)\space dx + \sum_{i=\space1}^{(N\space - \space 1)} a_i \cdot \int_0^L \varphi_i(x)\space dx + a_N \int_0^L  \varphi_N(x) ~dx)
# $$
# $$
# = \frac{1}{L} ( a_0 \cdot (\Delta x / 2 ) + \sum_{i=1}^{(N\space - \space 1)} a_i \Delta x + a_N \cdot (\Delta x / 2 ))
# $$
#
# $$
# c_0 \cdot \frac{L}{\Delta x}  =  \sum_{i= \space1}^{(N\space - \space 1)} a_i + \frac{1}{2} a_N +\frac{1}{2} a_0
# $$

# %% [markdown]
# # Aufgabe 2.3.2
# Berechnung der Koeffizienten wie in 2.2.1..
# Wir betrachten die drei nachfolgend aufgeführten Fälle.
#
# Der Operator $K_{kn}$ wird wie folgt definiert:
#
# - Wenn $(k)$ gleich $n$ ist, beträgt $K_{kn} = (\frac{2}{\Delta x})$
# - Wenn der Betrag von $(m - n)$ gleich 1 ist, beträgt $K_{kn} = \frac{-1}{\Delta x}$.
# - In allen anderen Fällen ist $K_{kn}$ gleich $0$.
#
# Aufgrund der periodische Randbedingung ist der Funktionswert von  Φ𝐵(rechter Rand)= Φ𝐴(linker Rand):
# Darum:
# $\Phi_A = \Phi_B \rightarrow a_0 = a_N$
#
# Die  Aufgabe 2.3.1 beschriebene Mittelwertbedinung  führt uns zu der Systemmatrix :
#
#
# $$
# \underline{K } = \frac{1}{\Delta x} \space \begin{pmatrix}
#                                        \space\space 1 & \space\space 0 &  \space\space0 & -1 \\
#                                         -1 & \space\space 2 & -1 & \space\space 0 \\
#                                          \space\space0 & -1 & \space\space 2 & -1 \\
#                                          0.5 & \space\space 1& \space\space1 & 0.5
#                                     \end{pmatrix}
# $$

# %% [markdown]
# # Aufgabe 2.2.3

# %%
import numpy as np

import matplotlib.pyplot as plt




L = 1.5
D = 0.8

DefBereich = np.linspace(0 ,L ,100)    

dx_4 = L/3
dx_7 =L/6


def fem_laplace_linear_1d_periodic(nb_grid_pts, dx, rhs_x):
#Function to solve the 1D Laplace equation with periodic 
# boundary conditions and an imposed average using a regular grid and linear finite elements. 
#Arguments 
#nb_grid_pts: int # Number of grid points 
   # dx: float #  Length between two adjacent grid points 
   # rhs_x: numpy.ndarray(nb_grid_pts) of floats #       Right-hand-side vector 
 
   # Returns 
   # func_x: numpy.ndarray(nb_grid_pts) of floats 
   #  Solution of the discretized 1D Laplace equation at  each grid point
    
    # K-Matrix definieren
    dig =  2 * np.ones(nb_grid_pts)  #Definition der  Diagonalen 
    ndig = -1 *  np.ones(nb_grid_pts-1)  #Definition der Nebendiagonal. # eins kürzer als hauptgerade

    K =  np.diag(dig) +  np.diag(ndig , 1)  + np.diag(ndig , -1)


    '''Änderung zeilen:'''

    ''' Zeile eins ( periodisch R_Bed)'''
    K[0, : ] =  0
    K[0, -1] = -1
    K[0, 0 ] =  1

    '''last line '''
    K[-1, : ] =  1 
    K[-1, 0 ] = 0.5
    K[-1, -1] = 0.5

    #Vorfactor
    K = 1/dx * K

    return np.linalg.solve(K , rhs_x)

# Für die Rechte Seite:
f_7 = ([0, 0 , 1/D , 0 , -1/D , 0 , (0.3*L) / (dx_7 **2)])
f_4 = ([0, 1/D , -1/D , (0.3*L) / (dx_4 **2)])

# plott
plt.figure()

#Fem Läesung 7
plt.plot(([0, 0.25, 0.5, 0.75, 1, 1.25, 1.5]), fem_laplace_linear_1d_periodic(7, dx_7, f_7), "r:", label = "N =7")
#Fem Lösung 4
plt.plot(([0, 0.5, 1, 1.5]), fem_laplace_linear_1d_periodic(4, dx_4, f_4),"*--", label = "N = 4")




#Analytisch
f_analystisch =  1/D  *  (-np.heaviside(DefBereich - L/3,0) * (DefBereich - L/3) + np.heaviside(DefBereich -2 * L / 3,0) * (DefBereich - 2 * L / 3) +  1/3 * DefBereich + 0.3*D)
plt.plot(DefBereich,f_analystisch,"green", label = "analytisch Loesung")


plt.ylabel("c(x) in m$^{-3}$")
plt.xlabel("Laenge ${L}$ in m")
plt.title(" A 2.3.3")
plt.legend()
plt.show()

# %% [markdown]
# # Aufgabe 2.4.1
#
# Lösung der Diffussionsgelichung mit Hilfe der Randbedingungen.$\\$
# Quellterm 1 : $f(x) = -\delta (x - \frac{L}{3}) + \delta (x - \frac{2L}{3})$
#
# Vernachlässigung des Quelltermns nach Dirichlet.$\varphi_0(x=0) = 1 $ und $\varphi_n(x=0) = 0$ solange n Element der Natrütlichen Zahlen ist. Erhalten wir:
# $$
# c_N(x) = c(x=0)= c_0 = a_0
# $$
# Somit ist die linke Randbedingung erfüllt.
#
#
#  Neumann Randbedinung
#
# $$
# (\varphi_k(x), R_N(x)) = D \cdot [\varphi_k(x) \frac{\partial c_N(x)}{\partial x} ]_a^b - D  \sum_{n=0}^{N} a_n ( \frac{\partial  \varphi_k}{\partial x}, \frac{\partial \varphi_n}{\partial x}) - (\varphi_k(x),f(x))\\
# (\varphi_k(x), R_N(x)) = 0
# $$
#
#
#  Rechte Randbedinung k = N, die basisfunktion ist am rechten Rand gleich 1 und am linken Rand gleich 0.
#  Die Konzentrationsänderung ist $c´_L$.
#
# $$
# (\varphi_N(x), R_N(x))   = Dc_L' - D \sum_{i= \space0}^N a_i\int_0^L  \frac{\partial \varphi_N}{\partial x} \frac{\partial \varphi_i}{\partial x}\space dx - \int_0^L \varphi_N(x)\cdot f(x) dx = 0
# $$
#
# Für $\int_0^L  \frac{\partial \varphi_N}{\partial x} \frac{\partial \varphi_i}{\partial x}\space dx$ erhalten wir für  n = N -> $\frac{1}{\Delta x}$ ; für n = N -1 -> $\frac{-1}{\Delta x}$ und für alle anderen Fälle erhalten wir -> 0. Somit :
# $$
# (\varphi_N(x), R_N(x)) = Dc_L'  - D [ a_{N-1}  \frac{-1}{\Delta x} ][ a_N \cdot \frac{1}{\Delta x} ] - \int_0^L \varphi_N(x)  \cdot f(x) dx
# $$
# $$
# (\varphi_N(x), R_N(x)) = 0
# $$
#
# Umgestellt erhalten wir:
# $$
# c_L' - \frac{1}{D}( \varphi_N(x),f(x) ) = (a_{N} - a_{N-1}) \cdot 1 / \Delta x
# $$
#
# damit erhaltn wir für den ersten Quellterm:
# $$
# c_L' - \frac{1}{D} \int_0^L \varphi_N(x) f(x)dx = (a_{N} - a_{N-1})  \cdot 1 / \Delta x  \\
# $$
#
# Da $\frac{1}{D} \int_0^L \varphi_N(x) f(x)dx = 0$ erhaltebn wir:
#
# $$
# c_L' = (a_{N} - a_{N-1})  \cdot 1 / \Delta x  \\
# $$
#
#
#
# Zweite Randbedingung $f_2(x) = f_0$. Auswertung rechte Seite mittels gleichung:
# $$
# c_L' - \frac{1}{D}( \varphi_N(x),f(x) ) = (a_{N} - a_{N-1}) \cdot 1 / \Delta x
# $$
#
# erhalten wir:
# $$
# c'_L - \frac{1}{D} (\varphi_N(x), f_2(x)) = (a_N - a_{N - 1}) \cdot 1 / \Delta x \\
# c'_L - \frac{1}{D} f_0 \frac{\Delta x}{2}  = (a_N - a_{N - 1}) \cdot 1 / \Delta x
# $$

# %% [markdown]
# # Aufgabe 2.4.2

# %%
import numpy as np
import matplotlib.pyplot as plt


def FEM_Laplace_Linear_1D(nb_grid_pts, dx, rhs_x, return_system_matrix = False): 
    """ 
    Function to solve the 1D Laplace equation with a 
    Dirichlet boundary condition and a Neumann boundary 
    condition using a regular grid and linear finite 
    elements. 
 
    Arguments 
    --------- 
    nb_grid_pts : int        Number of grid points 
    dx : float Length between two adjacent grid points 
    rhs_x : numpy.ndarray(nb_grid_pts) of floats         Right-hand-side vector 
    return_system_matrix : bool, optional    True if the system matrix should be returned.  (Default: False) 
 
    Returns 
    ------- 
    func_x : numpy.ndarray(nb_grid_pts) of floats 
        Solution of the discretized problem at each grid 
        point 
    system_matrix_xx : numpy.ndarray((nb_grid_pts, nb_grid_pts)) of floats 
        System matrix of the discretized problem. Is only 
        returned if the argument return_system_matrix is 
        True"""
    
    # K-Matrix definieren
    dig =  2 * np.ones(nb_grid_pts)  #Definition der  Diagonalen 
    ndig = -1 *  np.ones(nb_grid_pts - 1)  #Definition der Nebendiagonal

    K =  np.diag(dig) +  np.diag(ndig , 1)  + np.diag(ndig , -1)

    #Zeilen anpassen laut Aufgabe

    #Zeile 1 (Randbedinung links)
    K[0, :] = 0
    K[0, 0] = 1

    #Letze Zeile ( Randbedingung rechts)
    K[-1, :] =  0 
    K[-1,-1] =  1
    K[-1,-2] = -1

    #Vorfactor
    K = 1/dx * K

    #Rückgabe
    if return_system_matrix:
        return K

    #loesungsverktor
    return np.linalg.solve(K,rhs_x)




#Parameter 
L = 3
D_constant = 0.8


f_0 = 0.5
c_0_left = 2
c_L_right = 0.7

dx_4  = L / 3
dx_7  = L / 6
dx_10 = L / 9 


Defbereich= np.linspace(0,L,1000)  #100



#konsante Quelleterme
f_4konstant  = ([c_0_left/dx_4,   -f_0 * dx_4/D_constant ,   -f_0 * dx_4/D_constant ,    c_L_right - 1/D_constant  * f_0 * dx_4 / 2])
f_7konstant  = ([c_0_left/dx_7,   -f_0 * dx_7/D_constant ,   -f_0 * dx_7/D_constant ,   -f_0 * dx_7/D_constant ,   -f_0 * dx_7/D_constant ,   -f_0 * dx_7/D_constant ,  c_L_right - 1/D_constant  * f_0 * dx_7/2 ])
f_10konstant = ([c_0_left/dx_10,  -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant , -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant ,  -f_0 * dx_10/D_constant , c_L_right - 1/D_constant  * f_0 * dx_10/2 ])

#Distibution
f_4 = ([c_0_left/dx_4,  1/D_constant ,  -1/D_constant ,   c_L_right])
f_7 = ([c_0_left/dx_7,     0,            1/D_constant ,       0,           -1/D_constant ,  0,  c_L_right])
f_10 = ([c_0_left/dx_10,   0,               0,           1/D_constant ,          0,         0, -1/D_constant ,  0, 0,  c_L_right])






#Define Data

Data1 = list(range(4))      # [0, 1, 2, 3]

Data2= []                   # [0, 0.5, 1, 1.5, 2, 2.5, 3]
for i in range(0, 7):
    value = i * 0.5
    Data2.append(value)   

Data3 = []                  # [0, 0.33, 0.66, 1, 1.33, 1.66, 2, 2.33, 2.66, 3]
for i in range(10):
    value = i / 3
    Data3.append(value)







plt.figure("Quellterm Konstant")

plt.subplot(1,1,1)

#Loesung Analytisch QUellterm:
x = np.linspace(0,L,100)
c1 = c_L_right - (1/D_constant*f_0*L)
c2 = c_0_left
y = 1 / (2*D_constant) * f_0* x**2 + c1 *x + c2
plt.plot(x,y,label = "Loesung analytisch ermittelt")


#Finite-Elemente-Loesung

plt.plot((Data3), FEM_Laplace_Linear_1D(10, dx_10, f_10konstant), "g:",   label = "N = 10")
plt.plot((Data2), FEM_Laplace_Linear_1D(7, dx_7, f_7konstant),    "r+--", label = "N = 7")
plt.plot((Data1), FEM_Laplace_Linear_1D(4, dx_4, f_4konstant),    "b--",  label = "N = 4")


plt.legend()
plt.xlim(0,3)
plt.title("A 2.4.2 konstanter Quellterm")
plt.xlabel("Laenge in m")
plt.ylabel("Konzentration c  in  m$^{-3}$")
#plt.show()



#-----------------------------------------


#delta = '\u0394'
#plot function
plt.figure("delta Distribution")
plt.subplot(1,1,1)

#Finite-Elemente-Loesung
plt.plot((Data3), FEM_Laplace_Linear_1D(10, dx_10, f_10), "+--", label = "N = 10")
plt.plot((Data2), FEM_Laplace_Linear_1D(7,  dx_7,  f_7 ), "b--", label = "N = 7")
plt.plot((Data1), FEM_Laplace_Linear_1D(4,  dx_4,  f_4 ),"red",  label = "N = 4")





plt.legend()
plt.xlim(0,3)
plt.title("A 2.4.2 delta distribution")
plt.xlabel("Laenge in m")
plt.ylabel("Konzentration c  in m$^{-3}$")
plt.show()

# %% [markdown]
# Im Plott der -delta distribution- ist zuerkennen, dass die Lösungen im gewhählten intervall Deckungsgleich sind udn das obwohl eine unterschiedliche  Anzhal der Stützstellen gewählt wurde. Dies ist auf die teilweise positionierung im Dirac im Puls zurück zu führen.
#
# Im Plott -konstanter Quellterm- ist zu erkennen, dass je größer die Anzahl der Stützstellen, desto nähger kommt sie der analytischen Lösung.

# %% [markdown]
# # Aufgabe 2.5.1
#
#
#
# Residium der Poission Blotzmann Gleichung:
#
#
# $$
# R(x)  = \frac{\partial ^2 \Phi(x)}{\partial x^2} - \frac{\Phi(x)}{\lambda ^2}
# $$
#
# mit $\lambda = \sqrt{\frac{\varepsilon k_B T}{2c^{\infty}q^2}}$.
#
#
#
# Nun wie schon breits in Aufage 2.2.1:
#
#
# $$
# ( v(x) , R(x) ) = \int_{\Omega} v(x) \cdot R(x) dx = 0\\
# $$
#
#
# $$
# ( v(x) , R(x) ) = \int_{\Omega} v(x) \cdot (\frac{\partial ^2 \Phi(x)}{\partial  x^2} - \frac{\Phi(x)}{\lambda  ^2} ) \space dx \\
# $$
#
# $$
# ( v(x) , R(x) ) = v(x) \cdot \frac{\partial \Phi(x)}{\partial x}|_0^L - \int_\Omega \frac{\partial v(x)}{\partial x} \frac{\partial \Phi(x)}{\partial x}~dx - \int_\Omega v(x) \cdot  \frac{\Phi(x)}{\lambda^2} ~dx =
# $$
#
#
#
# Mit dem Galerkin Ansatz erhalten wir:
#
#
# $$
# (\varphi_k(x), R_N(x)) = \varphi_k(x) \cdot  \frac{\partial \Phi(x)}{\partial x}|_0^L - \sum_{i  =\space 0}^N a_i \int_\Omega \frac{\partial \varphi_k(x)}{\partial x} \cdot \frac{\partial \varphi_i(x)}{\partial x} \space dx  \space - \sum_{i =  \space 0}^N a_i \int_\Omega \varphi_k(x) \cdot  \frac{\varphi_i(x)}{\lambda^2} ~dx = 0 \\
# $$
#
#
# $$
# (\varphi_k(x), R_N(x)) =  \varphi_k(x) \cdot \frac{\partial \Phi(x)}{\partial x}|_0^L - \sum_{i = 0}^N a_i \cdot  [(\frac{\partial \varphi_k(x)}{\partial x} \cdot \frac{\partial \varphi_i(x)}{\partial x} dx) + ( \varphi_k(x),\frac{\varphi_i(x)}{\lambda^2} )
# $$
#
#
#
#
#
# $$
# ( v(x) , R(x) ) = 0 \space (\text{if}: \space |k-i|>1)
# $$

# %%
#2.5.2


#






# variablen
L     = 
Phi_1 = 
Phi_2 =
#............


# dx´s





def FEM_Poisson_Boltzmann_1D(nb_grid_pts, dx, debye_length, rhs_x): 
    """ 
    Function to solve the 1D Poisson Boltzmann equation with 
    two Dirichlet boundary conditions using a regular grid 
    and linear finite elements. 
 
    Arguments :
    

    nb_grid_pts : int 
        Number of grid points
        
    dx : float         Length between two adjacent grid points 
    
    debye_length : float         Debye length 
    rhs_x : numpy.ndarray(nb_grid_pts)           of floats          Right-hand-side vector 
 
    
    
    """
    # K matrix definition
    
    
    
    
    #first row
    
    
    
    #second row
    
    
    
    return np.linalg.solve(K,rhs_x)
    
    
    
# rechte Seite erstellen

    

    
#plott




##Finite-Elemente-Loesung


# analytische loesung
# Out:
#   Cell In[3], line 12
#     L     =
#             ^
# SyntaxError: invalid syntax
